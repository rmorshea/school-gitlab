# %% [markdown]
# Project Euler 19
# =

# %% [raw]
# You are given the following information, but you may prefer to do some research for yourself.
#
#     1 Jan 1900 was a Monday.
#     Thirty days has September,
#     April, June and November.
#     All the rest have thirty-one,
#     Saving February alone,
#     Which has twenty-eight, rain or shine.
#     And on leap years, twenty-nine.
#     A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
#
# How many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?

# %%
def find_month_days(m,y):
    if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
        d = 31
        return d
    elif m == 4 or m == 6 or m == 9 or m == 11:
        d = 30
        return d
    elif m == 2:
        if y%400 == 0:
            d = 29
            return d
        if y%100 == 0 and y%400 != 0:
            d = 28
            return d
        if y%4 == 0 and y%100 != 0:
            d = 29
            return d
        else:
            d = 28
            return d
    else:
        print "error"

M = {1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
        
W = {1:'Sun', 2:'Mon',3:'Tues',4:'Wed',5:'Thurs',6:'Fri',7:'Sat'}

def calculator(year_end):
    week_day = 1
    counter = 0
    counter_1 = 0
    for yr in range(1900,year_end+1):
        print '-'
        for month in range(1,13):
            a = find_month_days(month,yr)+1
            for month_days in range(1,a+1):
                week_day += 1
                if month_days == 1 and W[week_day] == 'Sun':
                    if yr == 1900:
                        counter = counter
                    else:
                        counter_1 = counter
                        counter += 1
                        print yr, M[month]
                if week_day >= 7:
                    week_day = 0
    
    print
    print 'TALLY TOTAL:'
    return counter

print calculator(2000)
# Out:
# -
# -
# 1901 January
# -
# -
# 1903 April
# 1903 June
# 1903 August
# 1903 October
# 1903 December
# -
# 1904 April
# 1904 June
# 1904 August
# 1904 October
# 1904 December
# -
# -
# 1906 February
# -
# 1907 March
# 1907 May
# 1907 July
# -
# 1908 March
# 1908 May
# 1908 July
# -
# 1909 September
# 1909 November
# -
# 1910 January
# -
# -
# -
# 1913 April
# 1913 June
# 1913 August
# 1913 October
# 1913 December
# -
# -
# 1915 February
# -
# -
# 1917 March
# 1917 May
# 1917 July
# -
# 1918 September
# 1918 November
# -
# 1919 January
# -
# -
# -
# 1922 April
# 1922 June
# 1922 August
# 1922 October
# 1922 December
# -
# -
# 1924 February
# -
# 1925 February
# -
# 1926 March
# 1926 May
# 1926 July
# -
# 1927 September
# 1927 November
# -
# 1928 January
# 1928 September
# 1928 November
# -
# 1929 January
# -
# -
# 1931 April
# 1931 June
# 1931 August
# 1931 October
# 1931 December
# -
# 1932 April
# 1932 June
# 1932 August
# 1932 October
# 1932 December
# -
# -
# 1934 February
# -
# ...
