# %%
#imports image and prints its dimensions and shape
from scipy import misc
lena = misc.lena()
print lena.ndim
print shape(lena)
# Out:
# 2
# (512, 512)

# %%
imshow(lena)

# %%
imshow(lena, cmap=cm.gray)

# %%
crop_lena = lena[30:-30,30:-30]
imshow(crop_lena)

# %%
y, x = np.ogrid[0:512,0:512]
centerx, centery = (256, 256)
mask = ((y - centery)**2 + (x - centerx)**2) > 230**2
lena[mask] = 0
imshow(lena)

# %%
y, x = np.ogrid[0:512,0:512]
center_x, center_y = (256, 256)
mask = ((y - center_y)**2/10 + (x - center_x)**2/4) > 50**2
lena[mask] = 0
imshow(lena)

# %% [raw]
# this is incomplet code because the image specified doesn't exist however if the file was on file and the path was correct this would print image dimensions and shape, then finaly save the image.

# %%
img = imread('/Users/RyanMorshead/Desktop/MG_0908.JPG')
imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-12-d702e91bbc2c> in <module>()
# ----> 1 img = imread('/Users/RyanMorshead/Desktop/MG_0908.JPG')
#       2 imshow(img)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imread(*args, **kwargs)
#    2044 @docstring.copy_dedent(_imread)
#    2045 def imread(*args, **kwargs):
# -> 2046     return _imread(*args, **kwargs)
#    2047
#    2048 @docstring.copy_dedent(_imsave)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in imread(fname, format)
#    1217
#    1218     if ext not in handlers.iterkeys():
# -> 1219         im = pilread(fname)
#    1220         if im is None:
#    1221             raise ValueError('Only know how to handle extensions: %s; with PIL installed matplotlib can handle more images' % handlers.keys())
#
# ...

# %%
print img.ndim
print np.shape(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a0bad5a71381> in <module>()
# ----> 1 print img.ndim
#       2 print np.shape(img)
#
# NameError: name 'img' is not defined

# %%
imsave('Guitar_1color', img[:,:,0], cmap=plt.cm.gray)
imshow(imread('Guitar_1color.JPG'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-06d2e4f6a784> in <module>()
# ----> 1 imsave('Guitar_1color', img[:,:,0], cmap=plt.cm.gray)
#       2 imshow(imread('Guitar_1color.JPG'))
#
# NameError: name 'img' is not defined
